# %%
# Run this cell first
import os
os.chdir("..")
# !git clone https://github.com/Darren-Kao/Moonshot-Bridge-Program-with-RabbitMQ
os.chdir("Moonshot-Bridge-Program-with-RabbitMQ")
# !pip install pika

# %%
# Run this cell after colabDealer to start the game. The game immediately starts when two separate instances of colabPlayer are active.
# !python player.py [replace this, including the brackets, with your CloudAMQP URL]
