# %%
# Run this cell first
import os
os.chdir("..")
# !git clone https://github.com/Darren-Kao/Moonshot-Bridge-Program-with-RabbitMQ
os.chdir("Moonshot-Bridge-Program-with-RabbitMQ")
# !pip install pika

# %%
# Run this cell before running colabPlayer instances to start the game
# !python dealer.py [replace this, including the brackets, with your CloudAMQP URL]
